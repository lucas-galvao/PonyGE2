# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 from pandas.plotting import autocorrelation_plot
#       5 from sklearn.metrics import mean_squared_error, mean_absolute_error
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
data = pd.read_csv('https://raw.githubusercontent.com/EraylsonGaldino/dataset_time_series/master/goldman.txt', header=None)
plt.plot(data)

# %%
autocorrelation_plot(data)
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(data, order=(1, 1, 1))
model_fit = model.fit()

# print(model_fit.summary())

yhat = model_fit.predict(len(data), len(data))
print(yhat)
# Out:
# 754    126.119736
# dtype: float64

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(data, order=(1, 1, 1), seasonal_order=(0, 0, 0, 0))
model_fit = model.fit(disp=False)

yhat = model_fit.predict(len(data), len(data))
print(yhat)
# Out:
# 754    126.087054
# dtype: float64

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

model = SimpleExpSmoothing(data)
model_fit = model.fit()

yhat = model_fit.predict(len(data), len(data))
print(yhat)
# Out:
# 754    126.134017
# dtype: float64

# %%
X = data[0].values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()

for t in range(len(test)):
    model = ARIMA(history, order=(1,1,1))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=88.526249, expected=89.620000
# predicted=89.666338, expected=91.980000
# predicted=91.825920, expected=91.360000
# predicted=91.528623, expected=89.520000
# predicted=89.455902, expected=87.790000
# predicted=87.929833, expected=88.660000
# predicted=88.492451, expected=88.090000
# predicted=88.268269, expected=92.890000
# predicted=92.496600, expected=92.290000
# predicted=92.673893, expected=92.130000
# predicted=91.792743, expected=91.000000
# predicted=91.359331, expected=92.240000
# predicted=91.854935, expected=95.790000
# predicted=95.962775, expected=97.180000
# predicted=96.957657, expected=98.590000
# predicted=98.722896, expected=96.400000
# predicted=96.385219, expected=95.150000
# predicted=95.223309, expected=101.610000
# predicted=101.238850, expected=104.890000
# predicted=105.069996, expected=105.930000
# predicted=105.719109, expected=105.390000
# predicted=105.605770, expected=106.050000
# predicted=105.824223, expected=105.470000
# predicted=105.701155, expected=105.750000
# predicted=105.527917, expected=108.880000
# predicted=108.936051, expected=106.890000
# predicted=106.932129, expected=108.590000
# predicted=108.471355, expected=110.510000
# predicted=110.526195, expected=110.460000
# predicted=110.447682, expected=114.490000
# predicted=114.317227, expected=114.350000
# predicted=114.512744, expected=112.980000
# predicted=112.894841, expected=113.140000
# predicted=113.209842, expected=112.880000
# predicted=112.828555, expected=111.170000
# predicted=111.293911, expected=111.570000
# predicted=111.439707, expected=109.950000
# predicted=110.141409, expected=110.240000
# predicted=110.053516, expected=111.770000
# predicted=111.869508, expected=112.910000
# predicted=112.768378, expected=113.610000
# predicted=113.706644, expected=111.400000
# predicted=116.585163, expected=116.440000
# predicted=116.507764, expected=116.060000
# predicted=116.016177, expected=118.630000
# predicted=118.555447, expected=119.250000
# predicted=119.289857, expected=116.760000
# predicted=116.833913, expected=118.160000
# predicted=118.030979, expected=117.570000
# predicted=117.712542, expected=116.640000
# predicted=116.553479, expected=117.240000
# predicted=117.291308, expected=115.440000
# predicted=115.472939, expected=115.990000
# predicted=115.936189, expected=116.060000
# predicted=116.105374, expected=115.430000
# predicted=115.416798, expected=115.870000
# predicted=115.862586, expected=117.700000
# predicted=117.626454, expected=116.940000
# predicted=117.039626, expected=117.340000
# predicted=117.232685, expected=118.190000
# predicted=118.249242, expected=122.280000
# predicted=122.046784, expected=126.520000
# predicted=126.544084, expected=126.010000
# predicted=126.010247, expected=128.450000
# predicted=128.344415, expected=127.190000
# predicted=127.340290, expected=126.290000
# predicted=126.194034, expected=125.920000
# predicted=126.022545, expected=125.430000
# predicted=125.358782, expected=124.290000
# predicted=124.403474, expected=126.310000

# %%
mae = mean_absolute_error(test, predictions)
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('Test MAE: %.3f' % mae)
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test MAE: 1.466
# Test MSE: 3.772
# Test RMSE: 1.942

# %%
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
residuo = test - predictions
plt.plot(residuo)

# %%
df = DataFrame(data)
df = concat([df.shift(1), df], axis=1)
df.fillna(-1, inplace=True)

values = df.values
X, y = values, values[:, 0]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(100, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(X, y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 24/24 [==============================] - 0s 21ms/step - loss: 11815.7139
# Epoch 2/200
# 24/24 [==============================] - 1s 21ms/step - loss: 2947.5815
# Epoch 3/200
# 24/24 [==============================] - 1s 21ms/step - loss: 243.1833
# Epoch 4/200
# 24/24 [==============================] - 0s 15ms/step - loss: 9.9907
# Epoch 5/200
# 24/24 [==============================] - 0s 16ms/step - loss: 8.7965
# Epoch 6/200
# 24/24 [==============================] - 0s 10ms/step - loss: 6.5653
# Epoch 7/200
# 24/24 [==============================] - 0s 17ms/step - loss: 6.0411
# Epoch 8/200
# 24/24 [==============================] - 0s 18ms/step - loss: 5.5802
# Epoch 9/200
# 24/24 [==============================] - 1s 22ms/step - loss: 5.2923
# Epoch 10/200
# 24/24 [==============================] - 0s 14ms/step - loss: 4.8330
# Epoch 11/200
# 24/24 [==============================] - 0s 13ms/step - loss: 4.4997
# Epoch 12/200
# 24/24 [==============================] - 0s 19ms/step - loss: 4.2421
# Epoch 13/200
# 24/24 [==============================] - 0s 11ms/step - loss: 3.8798
# Epoch 14/200
# 24/24 [==============================] - 0s 16ms/step - loss: 3.6044
# Epoch 15/200
# 24/24 [==============================] - 0s 15ms/step - loss: 3.2747
# Epoch 16/200
# 24/24 [==============================] - 0s 20ms/step - loss: 3.0733
# Epoch 17/200
# 24/24 [==============================] - 0s 16ms/step - loss: 2.7558
# Epoch 18/200
# 24/24 [==============================] - 0s 12ms/step - loss: 2.5180
# Epoch 19/200
# 24/24 [==============================] - 0s 19ms/step - loss: 2.2621
# Epoch 20/200
# 24/24 [==============================] - 0s 16ms/step - loss: 2.0791
